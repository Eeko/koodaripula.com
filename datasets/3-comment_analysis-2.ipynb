# %%
import pandas as pd;
#timestamps = pd.read_csv("answer_timestamps.csv")
#timestamps.set_index('Timestamp')
#timestamps.index = pd.to_datetime(timestamps["Timestamp"])
comments = pd.read_csv("answer_comments.csv")

# %%
#let's count and plot answers based on a comment prevalence
#make a function for this to make it more DRY
def print_comment_summary( column, plot_title ):
    comment_answers = comments.loc[comments[column] == True]
    print(comment_answers['Q1 CLASSIFICATION'].value_counts())
    print("---")
    print(comment_answers["Q2 CLASSIFICATION"].value_counts(normalize=True)) # get percentages of various respondent categories
    print("---")
    print(comment_answers["Q2 CLASSIFICATION"].value_counts().plot(kind="pie", title=plot_title)) # print a pie to make comparison to the main chart

# %%
print_comment_summary("COMMENT(INEFFICIENT_MANAGEMENT_HIRING_AND_WORK_PRACTICES)", "Mentions issues in management, hiring or work practices leading to need for more labor")
# Out:
# Y    13
# N     7
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER    0.45
# SPECIALIST    0.40
# GOVERNANCE    0.10
# MANAGEMENT    0.05
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
print(comments.loc[comments["COMMENT(INEFFICIENT_MANAGEMENT_HIRING_AND_WORK_PRACTICES)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ['Suspects a new "bubble" in the industry and claims most projects are unnecessary'
#  "Customers don't know what they want or can't communicate it well enough leading to a lot of unnecessary work. Once clients IT-knowledge develops, also the need for programming work will reduce."
#  'There are plenty of applicants. But despite degrees, they often lack the skills to work in a professional environment. On the other hand, organizing work often leads to more need for work. Quite often companies seek extra headcount when problems could be solved with other means'
#  "Mentions that the difficulty of finding new people makes it harder for organizations to re-invent themselves as people with antiquated skills can't push new ideas forward even if they would recognize the need."
# ...

# %%
print_comment_summary("COMMENT(TALENT_SHORTAGE_DISCOURSE_IS_NOT_WORKING)", "Presented frustration with the talent shortage discourse itself")
# Out:
# Y    7
# N    4
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER     0.545455
# SPECIALIST     0.090909
# GOVERNANCE     0.090909
# RECRUITMENT    0.090909
# OTHER          0.090909
# MANAGEMENT     0.090909
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
print(comments.loc[comments["COMMENT(TALENT_SHORTAGE_DISCOURSE_IS_NOT_WORKING)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ['Mentions that the discourse on talent shortage has twisted the market to absurd. Has talked with a number of sales directors sharing the opinion.'
# ...

# %%
print_comment_summary("COMMENT(INTERNATIONAL_LABOR)", "Mentioned international recruitment")
# Out:
# N    5
# Y    4
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER    0.555556
# SPECIALIST    0.333333
# GOVERNANCE    0.111111
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
print(comments.loc[comments["COMMENT(INTERNATIONAL_LABOR)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ['Lack of professionals in certain niches and the absolute best ones are not in Finland'
#  "Mentions Finnish Language requirements as an obstacle even though it should not be. Bad design choices lead to unnecessary work. Programmer shortafe is self-created by the industry. Many teams are only made from multiple senior developers, even though it would be better to have seniors mentoring juniors to ensure continuity. Senior developers support this structure as it's less effort for them and improves their wages"
# ...
