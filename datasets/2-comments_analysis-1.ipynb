# %%
import pandas as pd;
#timestamps = pd.read_csv("answer_timestamps.csv")
#timestamps.set_index('Timestamp')
#timestamps.index = pd.to_datetime(timestamps["Timestamp"])
comments = pd.read_csv("answer_comments.csv")

# %%
#let's count and plot answers based on a comment prevalence
#make a function for this to make it more DRY
def print_comment_summary( column, plot_title ):
    comment_answers = comments.loc[comments[column] == True]
    print(comment_answers['Q1 CLASSIFICATION'].value_counts())
    print("---")
    print(comment_answers["Q2 CLASSIFICATION"].value_counts(normalize=True)) # get percentages of various respondent categories
    print("---")
    print(comment_answers["Q2 CLASSIFICATION"].value_counts().plot(kind="pie", title=plot_title)) # print a pie to make comparison to the main chart

# %%
# who are the people who said the demand is specifically with senior engineers in the industry?
print_comment_summary("COMMENT(SENIORS_ENGINEERS_NEEDED)", "Mentions demand for senior engineers")
# Out:
# Y    44
# N    25
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER     0.623188
# SPECIALIST     0.217391
# RECRUITMENT    0.072464
# GOVERNANCE     0.072464
# MANAGEMENT     0.014493
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#let's print comments from that category
print(comments.loc[comments["COMMENT(SENIORS_ENGINEERS_NEEDED)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ["Surely a shortage of seniors. At least cheap seniors. Claims there's a greater shortage of customers who would be compatible with modern means of work, who pay decently and who respect software craftmanship."
#  'Does not think there is a shortage due to recent job seeking experiences. Has 3 years of experience and a university degree, but claims more experienced ones are always chosen. Also gets feedback that one\'s salary requirement (4k/month) scares employers, even though this one claims it\'s reasonable. Even though job advertisements claim they are for beginner/intermediate professionals with 1-3 years of experience, still more experienced ones apply and get the jobs. The "shortage" is for seniors with junior wages.'
#  'Shortage in exprienced programmers who can work independently and train juniors. Oversupply in common programmers.'
# ...

# %%
# who are the people who said the demand is specifically with senior engineers in the industry?
print_comment_summary("COMMENT(OFFERS_ARE_NOT_GOOD)", "Mentions problems with offers available")
# Out:
# N    38
# Y    12
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER    0.74
# SPECIALIST    0.22
# OTHER         0.04
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#let's print comments from that category
print(comments.loc[comments["COMMENT(OFFERS_ARE_NOT_GOOD)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ['Shortage of experienced developers who are not asking for too much in salary or are willing to move to capital region.'
#  'Developers easy to find. Finding exact matches hard. Suspects motive for "shortage" is for labour cost reductions with foreign labor.'
#  'Does not think there is a shortage due to recent job seeking experiences. Has 3 years of experience and a university degree, but claims more experienced ones are always chosen. Also gets feedback that one\'s salary requirement (4k/month) scares employers, even though this one claims it\'s reasonable. Even though job advertisements claim they are for beginner/intermediate professionals with 1-3 years of experience, still more experienced ones apply and get the jobs. The "shortage" is for seniors with junior wages.'
#  "Commitment issues with training juniors as they will pursue better salaries once trained to job. Headhunters end up taking thousands in comissions, but there's not enough for few hundreds in pay increases."
# ...

# %%
# Who are the people who said the industry is lacking entry paths to the profession?
print_comment_summary("COMMENT(LACK_OF_TRAINING_OR_ENTRY_PATHS_FOR_BEGINNERS_TO_INDUSTRY)", "Mentions problems with entry paths to industry")
# Out:
# N    21
# Y    21
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER     0.571429
# SPECIALIST     0.309524
# RECRUITMENT    0.047619
# GOVERNANCE     0.047619
# MANAGEMENT     0.023810
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#let's print comments from that category
print(comments.loc[comments["COMMENT(LACK_OF_TRAINING_OR_ENTRY_PATHS_FOR_BEGINNERS_TO_INDUSTRY)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ['Skilled, senior programmers are needed. Juniors have significant trouble landing jobs in current market.'
#  "Skilled programmers in short supply. Plenty of work for them. On the other hand, problem is that unemployed (and skilled) programmers are not matched with smaller companies looking for labor. On the other hand, problem might be that established companies don't have th courage to hire beginner programmers who might prove to be very skilled."
#  'More than lack of suitable candidates, the respondent says there\'s lack of willingness to train junior programmers. There\'s a lot of "5y experience on 3y old technology needed" style of advertisements. Also mentions the importance of luck, networks and hobby programming for landing jobs.'
#  'Many companies want out-of-the-box productvie employees and are not equipped to train workforce themselves from juniors. Working to train, retain and develop employees themselves would solve the recruitment troubles.'
# ...

# %%
# Who are the people who said there is very high or narrow bar for landing a job in the field?
print_comment_summary("COMMENT(TOO_HIGH_OR_SPECIFIC_SKILLS_REQUIRED_FOR_WORK)", "Mentions very high or specific skill requirements for jobs")
# Out:
# Y    25
# N    15
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER     0.600
# SPECIALIST     0.275
# MANAGEMENT     0.050
# GOVERNANCE     0.050
# RECRUITMENT    0.025
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
print(comments.loc[comments["COMMENT(TOO_HIGH_OR_SPECIFIC_SKILLS_REQUIRED_FOR_WORK)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ['Knows the country is full of unemployed skilled workers, but companies just require that wide array of skills from a person and/or knowledge in some obscure niche, which filters candidates out. No-one has time to train new workers'
#  '"Suitable professional" is too wide of a description. Suspects if companies could afford to spend a few months to train new programmers, there would be no shortage.'
# ...

# %%
# Who are the people who said entrants and beginners in the field are easy to find
print_comment_summary("COMMENT(BEGINNERS_AND_LESS_SKILLED_PROGRAMMERS_EASY_TO_FIND)", "Mentions that beginners are easy to find")
# Out:
# Y    26
# N     9
# Name: Q1 CLASSIFICATION, dtype: int64
# ---
# PROGRAMMER     0.600000
# SPECIALIST     0.228571
# GOVERNANCE     0.085714
# RECRUITMENT    0.057143
# MANAGEMENT     0.028571
# Name: Q2 CLASSIFICATION, dtype: float64
# ---
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
print(comments.loc[comments["COMMENT(BEGINNERS_AND_LESS_SKILLED_PROGRAMMERS_EASY_TO_FIND)"] == True]["KEY_TAKEAWAYS_FROM_COMMENTS"].sample(5).values)
# Out:
# ["Not much of shortage. The difficulty is more in finding the real rough diamonds from a pile of varied quality applicants. From 100 recruitments, maybe 10 have been good. From these half were juniors with less than 5 years of experience but with open minds and common sense. The most common toxic patterns with bad programmers: Wants to reinvent the wheel as it's fun. Does not care about budgets. Is used to using certain patterns and won't be willing to move out from comfort zone. Can't handle imperfections. Lack's motivation aside from monetary compensation and requires close supervision."
#  'Too many bad programmers are trained'
#  'Finland lacks good, fast learning programmers. Slow ones easy to find, but are not as efficient to justify similar earnings than better ones.'
#  'Skilled professionals in shortage. Basic programmers are available.'
#  'There are plenty of junior devs, but no willingness to hire them.']
